# %% [markdown]
# # Synthetic HW 4 walkthrough
# Synthetic byte-budget example: cat + newline + dog uses 7 bytes; bird does not fit.
# These cells have not been executed. The PNG is a schematic, not a benchmark.

# %%
from solution import budget_context
budget_context(["cat", "dog", "bird"], 8)
